# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# "Maven Fuzzy Factory" is the name of a fictitious E-Commerce website selling stuffed animals. In this notebook I'll conduct an exploration of the files to profile the data, discover issues with the it, and solve them. Although the data is synthetic it can be useful for demonstrating my skills as a data analyst.

# %% [markdown]
# ## Importing required libraries

# %%
import pandas as pd

# %% [markdown]
# ## Reading the data dictionary

# %% [markdown]
# The dataset comes with a data dictionary detailing the relationships between the different tables.

# %%
data_dict = pd.read_csv('raw/maven_fuzzy_factory_data_dictionary.csv')

# %% [markdown]
# How many tables does the dictionary describe?

# %%
list(data_dict['Table'].unique())
# Out:
# ['orders',
#  'order_items',
#  'order_item_refunds',
#  'products',
#  'website_sessions',
#  'website_pageviews']

# %% [markdown]
# The data dictionary packaged with the database seems to cover all (6) available files, let's explore them one by one.
#
# What are the characteristics of the `orders` table?

# %%
data_dict[data_dict['Table'] == 'orders']
# Out:
#     Table               Field  \
# 0  orders            order_id
# 1  orders          created_at
# 2  orders  website_session_id
# 3  orders             user_id
# 4  orders  primary_product_id
# 5  orders     items_purchased
# 6  orders           price_usd
# 7  orders            cogs_usd
#
#                                          Description
# 0              Unique identifier for each order (PK)
# 1                Timestamp when the order was placed
# 2     Unique identifier for the website session (FK)
# 3                Unique identifier for the user (FK)
# 4  Unique identifier for the primary product in t...
# 5                       Number of items in the order
# 6             Total price for the items in the order
# 7      Cost of goods sold for the items in the order

# %% [markdown]
# What are the characteristics of the `order_items` table?

# %%
data_dict[data_dict['Table'] == 'order_items']
# Out:
#           Table            Field  \
# 8   order_items    order_item_id
# 9   order_items       created_at
# 10  order_items         order_id
# 11  order_items       product_id
# 12  order_items  is_primary_item
# 13  order_items        price_usd
# 14  order_items         cogs_usd
#
#                                           Description
# 8          Unique identifier for each order item (PK)
# 9                 Timestamp when the order was placed
# 10  Unique identifier for the order the item belon...
# 11             Unique identifier for the product (FK)
# 12  Binary flag with a value of 1 if it's the prim...
# 13                               Price of the product
# 14                  Cost of goods sold of the product

# %% [markdown]
# What are the characteristics of the `order_item_refunds` table?

# %%
data_dict[data_dict['Table'] == 'order_item_refunds']
# Out:
#                  Table                 Field  \
# 15  order_item_refunds  order_item_refund_id
# 16  order_item_refunds            created_at
# 17  order_item_refunds         order_item_id
# 18  order_item_refunds              order_id
# 19  order_item_refunds     refund_amount_usd
#
#                                           Description
# 15             Unique identifier for each refund (PK)
# 16               Timestamp when the refund was issued
# 17  Unique identifier for the order item that was ...
# 18  Unique identifier for the order the refunded i...
# 19                                      Refund amount
